# %% [markdown]
# ## Generate figures that illustrate the fitting results as requested by a referee of the paper submitted to JAC 2016

# %% [markdown]
# - Copy the archived

# %%
# !cp /Users/yj/repo/evpsc/evpsc-github/20150427_BB_IF20k_5deg.tar ./
# !tar -xvf 20150427_BB_IF20k_5deg.tar
# Out:
# x igstrain_bix_ph1.out
# x igstrain_fbulk_ph1.out
# x int_els_ph1.out
# x STR_STR.OUT

# %%
# %pylab inline
import RS
from RS import rs_ex
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# - Ideal case (as a reference)

# %%
rst=rs_ex.ex_consistency(ig_sub=True,nfrq=20,psi_nbin=9,
                         iscatter=False,sigma=0., psimx=35.,
                         dec_inv_frq=1,hkl='211')
# Out:
# log has been saved to  ex_consistency.log
# Diff condition given to rs.DiffDat is not correct
# Diff condition given to rs.DiffDat is not correct
# No volume is given. Mask if sf==0
#      S11     S22     S33     S23     S13     S12
# processing: 00/100  +216.4  +232.4    +0.0    +0.0    +0.0    +0.0
# processing: 20/100  +418.9  +441.8    +0.0    +0.0    +0.0    +0.0
# processing: 40/100  +488.3  +502.2    +0.0    +0.0    +0.0    +0.0
# processing: 60/100  +534.0  +542.8    +0.0    +0.0    +0.0    +0.0
# processing: 80/100  +576.6  +578.8    +0.0    +0.0    +0.0    +0.0
# Elapsed time:          40 [sec]

# %% [markdown]
# - ideal case except that IG strain is discarded.

# %%
rst=rs_ex.ex_consistency(ig_sub=False,nfrq=20,psi_nbin=9,
                         iscatter=False,sigma=0., psimx=35.,
                         dec_inv_frq=1,hkl='211')
# Out:
# log has been saved to  ex_consistency.log
# Diff condition given to rs.DiffDat is not correct
# Diff condition given to rs.DiffDat is not correct
# No volume is given. Mask if sf==0
#      S11     S22     S33     S23     S13     S12
# processing: 00/100  +214.0  +241.3    +0.0    +0.0    +0.0    +0.0
# processing: 20/100  +452.1  +477.7    +0.0    +0.0    +0.0    +0.0
# processing: 40/100  +527.5  +544.9    +0.0    +0.0    +0.0    +0.0
# processing: 60/100  +577.5  +577.9    +0.0    +0.0    +0.0    +0.0
# processing: 80/100  +593.8  +583.7    +0.0    +0.0    +0.0    +0.0
# Elapsed time:          39 [sec]

# %% [markdown]
# - perturbed result

# %%
rst=rs_ex.ex_consistency(ig_sub=True,nfrq=20,psi_nbin=9,
                         iscatter=True,sigma=25.e-6, psimx=35.,
                         dec_inv_frq=1,hkl='211',theta_b=78.2*np.pi/180.,
                         ird=0.182)
# Out:
# log has been saved to  ex_consistency.log
# Diff condition given to rs.DiffDat is not correct
# Diff condition given to rs.DiffDat is not correct
# No volume is given. Mask if sf==0
#      S11     S22     S33     S23     S13     S12
# processing: 00/100  +218.7  +245.3    +0.0    +0.0    +0.0    +0.0
# processing: 20/100  +428.9  +423.1    +0.0    +0.0    +0.0    +0.0
# processing: 40/100  +489.9  +505.1    +0.0    +0.0    +0.0    +0.0
# processing: 60/100  +546.4  +577.7    +0.0    +0.0    +0.0    +0.0
# processing: 80/100  +563.7  +623.5    +0.0    +0.0    +0.0    +0.0
# Elapsed time: 01 [min] 00 [sec]
